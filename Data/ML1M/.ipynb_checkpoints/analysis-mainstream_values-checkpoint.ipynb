# %%
import numpy as np
import pickle
import pandas as pd
from tqdm import tqdm
from math import log
from scipy.sparse import coo_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew
from scipy.stats import mode

# %%
MSV_Jsim = np.load('./MSV_Jsim.npy')
MSV_Csim = np.load('./MSV_Csim.npy')
MSV_Asim = np.load('./MSV_Asim.npy')
MSV_DeepSVDD = np.load('./MSV_DeepSVDD.npy')

num_user = len(MSV_DeepSVDD)

# %%
df = pd.DataFrame({'MSV_Jsim': MSV_Jsim, 'MSV_Csim': MSV_Csim, 'MSV_Asim': MSV_Asim, 'MSV_DeepSVDD': MSV_DeepSVDD})

# %%
sns.displot(data=df, x="MSV_Jsim", y="MSV_Csim")

# %%
sns.displot(data=df, x="MSV_Jsim", y="MSV_Asim")

# %%
sns.displot(data=df, x="MSV_Jsim", y="MSV_DeepSVDD")

# %%
plt.rcParams.update({'font.size': 10})
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
axes.scatter(np.arange(num_user), sorted(MSV_Jsim), alpha=0.9, marker='o', s=5)
axes.grid(True)
fig.tight_layout()
fig.patch.set_facecolor('white')
plt.show()

# %%
plt.rcParams.update({'font.size': 10})
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
axes.scatter(np.arange(num_user), sorted(MSV_Csim), alpha=0.9, marker='o', s=5)
axes.grid(True)
fig.tight_layout()
fig.patch.set_facecolor('white')
plt.show()

# %%
plt.rcParams.update({'font.size': 10})
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
axes.scatter(np.arange(num_user), sorted(MSV_Asim), alpha=0.9, marker='o', s=5)
axes.grid(True)
fig.tight_layout()
fig.patch.set_facecolor('white')
plt.show()

# %%
plt.rcParams.update({'font.size': 10})
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(6, 4))
axes.scatter(np.arange(num_user), sorted(MSV_DeepSVDD), alpha=0.9, marker='o', s=5)
axes.grid(True)
fig.tight_layout()
fig.patch.set_facecolor('white')
plt.show()

# %%
def distribution_plot(x, y, bins=20):
    x_max = np.max(x)
    x_min = np.min(x)
    step = (x_max - x_min) / bins
    x_array = []
    mean_array = []
    std_array = []
    for i in range(bins):
        start = x_min + step * i
        end = x_min + step * (i + 1)
        x_array.append((start + end) / 2)
        tmp = y[np.where((x >= start) & (x <= end))[0]]
        mean_array.append(np.mean(tmp) if len(tmp) > 0 else 0)
        std_array.append(np.std(tmp) if len(tmp) > 0 else 0)
    print(x_array)
    print(mean_array)
    print(std_array)
    plt.rcParams.update({'font.size': 15})
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))
    axes.bar(x_array, mean_array, yerr=std_array, align='center', alpha=0.7, ecolor='black', capsize=5, width=step / 2)
    axes.grid(True)
    axes.set_ylim(0., 1.1)
    fig.tight_layout()
    fig.patch.set_facecolor('white')
    plt.show()
    print('### gini coefficient = %.6f ###' % gini_coefficient(mean_array))

# %%
distribution_plot(mainstream_value[valid_users], ndcg[valid_users], bins=5)

# %%
tmp_user = mainstream_value[valid_users]
user_sort_idx = np.argsort(tmp_user)
tmp_ndcg = ndcg[valid_users]
distribution_plot(np.arange(len(valid_users)), tmp_ndcg[user_sort_idx], bins=5)

# %%
tmp_user_pop = user_pop[valid_users]
user_sort_idx = np.argsort(tmp_user_pop)
tmp_ndcg = ndcg[valid_users]
distribution_plot(np.arange(len(valid_users)), tmp_ndcg[user_sort_idx], bins=5)

# %%
gini_coefficient(tmp_ndcg[user_sort_idx])

# %%
distribution_plot(user_pop[valid_users], ndcg[valid_users], bins=20)

# %%
# plt.rcParams.update({'font.size': 20})
# fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))
# for u in range(num_user):
#     if np.random.random() > 0.995:
#         sns.kdeplot(Jaccard_mat[u, :], ax=axes)
# axes.grid(True)
# fig.tight_layout()
# fig.patch.set_facecolor('white')
# plt.show()
